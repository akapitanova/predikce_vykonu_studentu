# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Nahrání dat

# %%
def readFilesFromDirectory(dirName):
    fileNames = []
    pandasNames = []
    with os.scandir(dirName) as entries:
        for entry in entries:
            if entry.name[0] != '.':
                fileNames.append(entry.name)
                name = entry.name[0:-4].split('_')
                pandasNames.append(name[-2] + '_' + name[-1])
    return fileNames, pandasNames

# %%
fileNames, pandasNames = readFilesFromDirectory('data')

# %%
fileNames
# Out:
# ['dm_vysledky_studentu_v_predmetech_mv_prihlaska_dim.csv',
#  'dm_vysledky_studentu_v_predmetech_mv_klasifikace_fact.csv',
#  'dm_vysledky_studentu_v_predmetech_mv_predmet_dim.csv',
#  'dm_vysledky_studentu_szzk_mv_zaverecne_prace_fact.csv',
#  'dm_vysledky_studentu_szzk_mv_szzk_dim.csv',
#  'dm_vysledky_studentu_v_predmetech_mv_student_dim.csv',
#  'dm_vysledky_studentu_v_predmetech_mv_studium_dim.csv',
#  'dm_vysledky_studentu_v_predmetech_mv_semestr_dim.csv',
#  'dm_vysledky_studentu_szzk_mv_zaverecne_prace_dilci_hodnoceni_dim.csv']

# %%
pandasNames
# Out:
# ['prihlaska_dim',
#  'klasifikace_fact',
#  'predmet_dim',
#  'prace_fact',
#  'szzk_dim',
#  'student_dim',
#  'studium_dim',
#  'semestr_dim',
#  'hodnoceni_dim']

# %%
path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_prihlaska_dim.csv'])
prihlaska_dim = pd.read_csv(path_file, sep=";") 

path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_klasifikace_fact.csv'])
klasifikace_fact = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_predmet_dim.csv'])
predmet_dim = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_szzk_mv_zaverecne_prace_fact.csv'])
prace_fact = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_szzk_mv_szzk_dim.csv'])
szzk_dim = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_student_dim.csv'])
student_dim = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_studium_dim.csv'])
studium_dim = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_v_predmetech_mv_semestr_dim.csv'])
semestr_dim = pd.read_csv(path_file, sep=";")

path_file = os.sep.join(['data', 'dm_vysledky_studentu_szzk_mv_zaverecne_prace_dilci_hodnoceni_dim.csv'])
hodnoceni_dim = pd.read_csv(path_file, sep=";")

# %% [markdown]
# # Informace o datasetech

# %% [markdown]
# ### prihlaska_dim

# %%
prihlaska_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599 entries, 0 to 3598
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cislo_prihlasky              3599 non-null   int64
#  1   odkud_uchazec_prihlasen_kod  1154 non-null   float64
#  2   prihlaska_kod                3599 non-null   int64
#  3   studium_id                   3599 non-null   int64
#  4   rozhodnuti_kod               3594 non-null   float64
#  5   obor_ss_kod                  613 non-null    object
#  6   ss_izo                       892 non-null    float64
#  7   ss_typ                       866 non-null    float64
#  8   ss_predmet1                  29 non-null     object
#  9   ss_predmet2                  27 non-null     object
#  10  ss_predmet3                  1 non-null      object
#  11  ss_predmet4                  1 non-null      object
#  12  ss_predmet5                  0 non-null      float64
# ...

# %%
prihlaska_dim.loc[:, 'financovani'].dropna()
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 3594    69
# 3595    69
# 3596     6
# 3597    51
# 3598    69
# Name: financovani, Length: 3599, dtype: int64

# %%
prihlaska_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599 entries, 0 to 3598
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cislo_prihlasky              3599 non-null   int64
#  1   odkud_uchazec_prihlasen_kod  1154 non-null   float64
#  2   prihlaska_kod                3599 non-null   int64
#  3   studium_id                   3599 non-null   int64
#  4   rozhodnuti_kod               3594 non-null   float64
#  5   obor_ss_kod                  613 non-null    object
#  6   ss_izo                       892 non-null    float64
#  7   ss_typ                       866 non-null    float64
#  8   ss_predmet1                  29 non-null     object
#  9   ss_predmet2                  27 non-null     object
#  10  ss_predmet3                  1 non-null      object
#  11  ss_predmet4                  1 non-null      object
#  12  ss_predmet5                  0 non-null      float64
# ...

# %%
prihlaska_dim_o = prihlaska_dim.copy(deep=True)
prihlaska_dim = prihlaska_dim.loc[:, ['cislo_prihlasky', 
                                      'odkud_uchazec_prihlasen_kod', 
                                      'prihlaska_kod', 
                                      'studium_id', 
                                      'rozhodnuti_kod', 
                                      'obor_ss_kod', 
                                      'ss_izo', 
                                      'ss_typ', 
                                      'predchozi_studium', 
                                      'maturita_rok', 
                                      'hodnoceni_pz', 
                                      'trvaly_pobyt_v_cr', 
                                      'financovani', 
                                      'stupen_predchoziho_vzdelani', 
                                      'cislo_uchazece', 
                                      'scio_test', 
                                      'olympiady', 
                                      'postizeni_kod', 
                                      'datum_registrace', 
                                      'misto_kod', 
                                      'okres_kod', 
                                      'zeme_kod', 
                                      'psc']]

# %%
prihlaska_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3599 entries, 0 to 3598
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cislo_prihlasky              3599 non-null   int64
#  1   odkud_uchazec_prihlasen_kod  1154 non-null   float64
#  2   prihlaska_kod                3599 non-null   int64
#  3   studium_id                   3599 non-null   int64
#  4   rozhodnuti_kod               3594 non-null   float64
#  5   obor_ss_kod                  613 non-null    object
#  6   ss_izo                       892 non-null    float64
#  7   ss_typ                       866 non-null    float64
#  8   predchozi_studium            633 non-null    object
#  9   maturita_rok                 1629 non-null   float64
#  10  hodnoceni_pz                 2136 non-null   float64
#  11  trvaly_pobyt_v_cr            3145 non-null   object
#  12  financovani                  3599 non-null   int64
# ...

# %%
prihlaska_dim
# Out:
#       cislo_prihlasky  odkud_uchazec_prihlasen_kod  prihlaska_kod  studium_id  \
# 0                   2                          NaN     2788685710     1754706
# 1                   3                          NaN     7392860610     1754806
# 2                   4                          NaN     5222013410     1754906
# 3                   5                          NaN     1489038810     1755006
# 4                   6                          NaN     7970815610     1755106
# ...               ...                          ...            ...         ...
# 3594             2354                          NaN     9774758712    18653606
# 3595             2355                          NaN     1580023012    18668306
# 3596             2829                          NaN     4603991912    18683206
# 3597             2358                          NaN     7430312812    18688006
# 3598             2359                          NaN     1277700212    18688106
#
# ...

# %% [markdown]
# ### klasifikace_fact

# %%
klasifikace_fact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280632 entries, 0 to 280631
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   semestr_id     280632 non-null  object
#  1   predmet_id     280632 non-null  int64
#  2   studium_id     280632 non-null  int64
#  3   zapocteno      193675 non-null  object
#  4   zakonceno      179228 non-null  float64
#  5   znamka         175217 non-null  float64
#  6   poradi_zapisu  280632 non-null  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 15.0+ MB

# %%
predmet_dim[predmet_dim.kod_predmetu == 'BI-ZMA']
# Out:
#      predmet_id kod_predmetu               nazev_predmetu  pocet_kreditu  \
# 585     1122106       BI-ZMA  Základy matematické analýzy            6.0
#
#     typ_predmetu forma_studia uroven_studia zpusob_zakonceni jazyk_vyuky
# 585            P            P             B             Z,ZK          CS

# %%
klasifikace_fact_o[klasifikace_fact_o.predmet_id == 1122106]['znamka'].value_counts()
# Out:
# 4.0    1451
# 2.5    1302
# 2.0    1019
# 3.0     872
# 1.5     609
# 1.0     299
# Name: znamka, dtype: int64

# %%
klasifikace_fact['semestr_id'].unique()
# Out:
# array(['B202', 'B201', 'B192', 'B191', 'B182', 'B181', 'B172', 'B171',
#        'B162', 'B161', 'B152', 'B151', 'B142', 'A000', 'B211', 'B141',
#        'B131', 'B122', 'B132', 'B121', 'B102', 'B111', 'B112', 'B101',
#        'B091', 'B092'], dtype=object)

# %%
klasifikace_fact_o = klasifikace_fact.copy(deep=True)
klasifikace_fact = klasifikace_fact.loc[:, :]

# %%
courses_zaznamy = klasifikace_fact[(klasifikace_fact['semestr_id'].isin(['B202', 'B201', 'B192', 'B191', 'B182', 'B181', 'B172', 'B171',
       'B162', 'B161', 'B152', 'B151'])) 
                 & (klasifikace_fact['znamka'].notna())]

# %%
courses_zaznamy.describe()
# Out:
#          predmet_id    studium_id  zakonceno        znamka  poradi_zapisu
# count  9.520400e+04  9.520400e+04    86113.0  95204.000000   95204.000000
# mean   2.352150e+06  1.393828e+07        1.0      2.040907       1.066720
# std    1.500233e+06  2.687494e+06        0.0      0.909453       0.249748
# min    1.110806e+06  4.749606e+06        1.0      1.000000       1.000000
# 25%    1.122206e+06  1.173968e+07        1.0      1.000000       1.000000
# 50%    1.442406e+06  1.426911e+07        1.0      2.000000       1.000000
# 75%    3.458606e+06  1.564041e+07        1.0      2.500000       1.000000
# max    6.609806e+06  1.888941e+07        1.0      4.000000       4.000000

# %%
sem = ['B202', 'B201', 'B192', 'B191', 'B182', 'B181', 'B172', 'B171',
       'B162', 'B161', 'B152', 'B151']

# %%
courses = klasifikace_fact[(klasifikace_fact['semestr_id'].isin(sem)) 
                 & (klasifikace_fact['znamka'].notna())]['predmet_id'].unique()

# %%
courses
# Out:
# array([1431806, 1477606, 6291506, 1439406, 3181506, 3317206, 2961006,
#        2424806, 5431406, 1432806, 1435606, 1438106, 1438206, 2779306,
#        2961106, 1448006, 1434306, 1447906, 4730506, 2375506, 1447206,
#        1431206, 1125006, 1678706, 2822906, 4669606, 1435006, 1469206,
#        4257206, 1122406, 1477406, 1808806, 3459206, 5073606, 5077306,
#        2379506, 1433006, 1434506, 5124306, 5077206, 1123606, 1443906,
#        1444806, 5712406, 1445206, 1435506, 2052906, 1123006, 1997106,
#        1810806, 3319306, 2200806, 2162806, 2822806, 2302906, 2532806,
#        2358206, 2302806, 2055206, 3319206, 3467706, 5712106, 4651706,
#        3429206, 2779106, 1336206, 1125606, 2410806, 1445706, 4903306,
#        1121706, 1440706, 2384806, 3462706, 3469906, 1125806, 2778806,
#        5555206, 4653106, 4767806, 1125406, 3472006, 2960906, 1441606,
#        1434006, 1433806, 1125306, 1440506, 1439006, 1440806, 1808906,
# ...

# %% [markdown]
# ### predmet_dim

# %%
predmet_dim
# Out:
#       predmet_id kod_predmetu                 nazev_predmetu  pocet_kreditu  \
# 0        1383306       BI-ZTK        Tělovýchovný kurz zimní            0.0
# 1        1383406       BI-LTK        Tělovýchovný kurz letní            0.0
# 2        1451306      BI-LTK2     Tělovýchovný kurz letní II            0.0
# 3        1451406      BI-ZTK2     Tělovýchovný kurz zimní II            0.0
# 4        1451706       BI-TV4             Tělesná výchova IV            0.0
# ...          ...          ...                            ...            ...
# 1182     6703306    BI-HWB.21          Hardwarová bezpečnost            5.0
# 1183     3459606       BI-HWB          Hardwarová bezpečnost            5.0
# 1184     6624806      NIE-SBF  System Security and Forensics            5.0
# 1185     6559906   BIK-ZSB.21  Základy systémové bezpečnosti            5.0
# 1186     6813906      NIE-BLO                     Blockchain            5.0
#
# ...

# %%
predmet_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   predmet_id        1187 non-null   int64
#  1   kod_predmetu      1187 non-null   object
#  2   nazev_predmetu    1187 non-null   object
#  3   pocet_kreditu     1181 non-null   float64
#  4   typ_predmetu      1133 non-null   object
#  5   forma_studia      1007 non-null   object
#  6   uroven_studia     1144 non-null   object
#  7   zpusob_zakonceni  1187 non-null   object
#  8   jazyk_vyuky       1038 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 83.6+ KB

# %%
predmet_dim_o = predmet_dim.copy(deep=True)
predmet_dim = predmet_dim.loc[:, :]

# %%
courses_dot = predmet_dim[(predmet_dim['kod_predmetu'].str.contains("\.", case=False))]['kod_predmetu'].unique()

# %%
#slovnik predmet_id: kod_predmetu
courses_bak_tran_id_kod = dict()
for index, row in predmet_dim.iterrows():
    courses_bak_tran_id_kod[row['predmet_id']] = row['kod_predmetu']
    
#slovnik kod_predmetu: predmet_id
courses_bak_tran_kod_id = dict()
for index, row in predmet_dim.iterrows():
    courses_bak_tran_kod_id[row['kod_predmetu']] = row['predmet_id']

# %%
courses_dot_id = []
for course in courses_dot:
    courses_dot_id.append(courses_bak_tran_kod_id[course])

# %%
courses_dot_class = klasifikace_fact_o[klasifikace_fact_o['predmet_id'].isin(courses_dot_id)]

# %%
courses_dot_class
# Out:
#        semestr_id  predmet_id  studium_id zapocteno  zakonceno  znamka  \
# 7487         B211     6547806    18589206       NaN        NaN     NaN
# 13402        B172     5431406     9219406         Z        1.0     1.5
# 13403        B172     5431406     9172306         Z        1.0     3.0
# 18781        B211     2950806    19547806       NaN        NaN     NaN
# 18782        B202     2950806    17201506       NaN        1.0     NaN
# ...           ...         ...         ...       ...        ...     ...
# 280371       B172     4675306    15054006         Z        1.0     1.0
# 280372       B172     4675306    15006506         Z        1.0     2.5
# 280373       B172     4675306    15078506         Z        1.0     1.5
# 280374       B172     4675306    13979306         Z        1.0     2.0
# 280375       B162     4675306    13588906         Z        1.0     1.0
#
#         poradi_zapisu
# 7487                1
# 13402               1
# 13403               1
# ...

# %%
courses_dot_class_id = courses_dot_class['predmet_id'].unique()
courses_dot_class_kod = []
for course in courses_dot_class_id:
    courses_dot_class_kod.append(courses_bak_tran_id_kod[course])

# %%
courses_dot_class_kod
# Out:
# ['BIK-BPR.21',
#  'BI-AWD.1',
#  'PI-AWR.1',
#  'PI-FME.1',
#  'BIE-SP2.1',
#  'BIE-SI2.2',
#  'BIE-EPD.2',
#  'MIE-ADP.16',
#  'BI-PJS.1',
#  'BI-SQL.1',
#  'BIK-EPD.2',
#  'BIK-SQL.1',
#  'MI-FME.16',
#  'BIK-SI2.2',
#  'BI-SI1.2',
#  'BIE-SP2.2',
#  'MIE-FME.16',
#  'MI-NSS.16',
#  'BIK-SP2.1',
#  'BI-TWA.1',
#  'MI-W20.16',
#  'MIE-PIS.16',
#  'MIE-W20.16',
#  'MIE-MDW.16',
#  'BI-FTR.1',
#  'MIE-PDB.16',
#  'MI-PIS.16',
#  'BIE-SI1.2',
#  'BI-SI2.2',
#  'MI-DDW.16',
#  'MIE-DDW.16',
#  'BI-PHP.1',
#  'BI-SI2.3',
#  'MI-PCM.16',
#  'MI-MDW.16',
#  'MI-MEP.16',
#  'MI-PDB.16',
#  'MI-ADP.16',
#  'MI-VMM.16',
#  'BIK-SI2.3',
#  'BIK-SI1.2',
#  'BI-SP2.1',
#  'MI-NUR.16',
#  'BI-EPD.2',
#  'MIE-NUR.16',
#  'MI-MBI.16',
#  'MI-SMI.16',
#  'BI-PYT.1',
#  'BI-3DT.1',
#  'BI-MVT.21',
#  'MI-SWE.16',
#  'BI-PGR.1',
#  'MIE-SWE.16',
#  'BIK-PRR.21',
#  'BI-PYT.21',
#  'BIE-3DT.1',
#  'BIE-TWA.1',
#  'BIE-PHP.1',
#  'BIE-PRR.21',
#  'BI-GIT.21',
#  'BIE-GIT.21',
#  'BIK-GIT.21',
# ...

# %%
predmet_dim[predmet_dim['kod_predmetu'] == 'BI-ADW']
# Out:
#      predmet_id kod_predmetu           nazev_predmetu  pocet_kreditu  \
# 950     1124406       BI-ADW  Administrace OS Windows            5.0
#
#     typ_predmetu forma_studia uroven_studia zpusob_zakonceni jazyk_vyuky
# 950           PO            P             B             Z,ZK          CS

# %%
len(klasifikace_fact[klasifikace_fact['predmet_id'] == 1124406])
# Out:
# 357

# %%
klasifikace_fact[klasifikace_fact['predmet_id'] == 1124406]
# Out:
#        semestr_id  predmet_id  studium_id zapocteno  zakonceno  znamka  \
# 237869       B141     1124406     7833906         Z        1.0     1.0
# 237870       B141     1124406     4777006       NaN        NaN     NaN
# 237871       B131     1124406     3719006         Z        1.0     2.0
# 237872       B131     1124406     6319706         Z        1.0     2.0
# 237873       B131     1124406     3762206         N        NaN     NaN
# 237874       B131     1124406     6304906         Z        1.0     1.5
# 237875       B101     1124406     4220106         Z        1.0     2.0
# 237876       B101     1124406     1602806         Z        1.0     1.5
# 237877       B131     1124406     6259806         Z        1.0     1.5
# 237878       B131     1124406     4795206         Z        1.0     1.5
# 237879       B141     1124406     7844606         Z        1.0     1.5
# 237880       B151     1124406     9196006         Z        1.0     2.5
# ...

# %%
len(klasifikace_fact[klasifikace_fact['predmet_id'] == 3458006])
# Out:
# 447

# %%
predmet_dim[(predmet_dim['kod_predmetu'].str.contains("bi-", case=False))]['kod_predmetu'].unique()
# Out:
# array(['BI-ZTK', 'BI-LTK', 'BI-LTK2', 'BI-ZTK2', 'BI-TV4', 'BI-TV3',
#        'BI-TV2', 'BI-TV1', 'BI-SV', 'BI-BIG.1', 'BI-VOL', 'BI-VZD.1',
#        'BI-SRC.1', 'BI-JPO.1', 'BI-PJP.1', 'BI-PVE', 'BI-PRP.1',
#        'BI-MGA.1', 'BI-PNO.1', 'BI-PVH', 'BI-PS1.1', 'BI-BAP',
#        'BI-BPR.21', 'BI-BAP.21', 'BI-BPR', 'BI-WMM', 'BI-PHP', 'BI-SI1',
#        'BI-SI2', 'BI-3DT', 'BI-TWA', 'BI-BPZS', 'BI-MII', 'BI-ATS',
#        'BI-EKP', 'BI-AWD.1', 'BI-EPD', 'BI-VWM.1', 'BI-FTR', 'BI-EHD',
#        'BI-FIP', 'BI-ZSI', 'BI-PCS', 'BI-ZS10', 'BI-ZS30', 'BI-ZS20',
#        'BI-DBS', 'BI-APJ', 'BI-DAN', 'BI-A1Z', 'BI-A2Z', 'BI-A0Z',
#        'BI-DPR', 'BI-CS2', 'BI-ANG1', 'BI-PJS.1', 'BI-ZNF', 'BI-SP1',
#        'BI-TDA', 'BI-PWT', 'BI-OMO', 'BI-WT1', 'BI-SQL.1', 'BI-ZPI',
#        'BI-ZWU', 'BI-WT2', 'BI-KOT', 'BI-OPJ', 'BI-PJV', 'BI-SP2',
#        'BI-MIK', 'BI-PAI', 'BI-MEK', 'BI-TJV', 'BI-TIS', 'BI-SI1.2',
#        'BI-PRP', 'BI-MMP', 'BI-PPR', 'BI-TWA.1', 'BI-PJS', 'BI-PGR',
# ...

# %%
predmet_dim['uroven_studia'].unique()
# Out:
# array(['B', 'B;', nan, 'B;M;', 'D;', 'M', 'M;', 'D', '0', '0;', 'D;M;'],
#       dtype=object)

# %%
predmet_dim['forma_studia'].unique()
# Out:
# array(['P', 'K', nan], dtype=object)

# %%
predmet_dim[(predmet_dim['uroven_studia'].isna())]
# Out:
#       predmet_id kod_predmetu  \
# 7        1750806          U3V
# 13       3468406    BIE-ZMA.1
# 14       3472506    BIK-ZMA.1
# 15       3458806     BI-BIG.1
# 16       3463106       BI-VOL
# 17       3463306     BI-VZD.1
# 18       3462406     BI-SRC.1
# 19       3459706     BI-JPO.1
# 20       3466606    BIE-PS1.1
# 21       3467206    BIE-SI1.1
# 22       3470306    BIK-LIN.1
# 23       3461006     BI-PJP.1
# 24       3461706       BI-PVE
# 25       3461306     BI-PRP.1
# 26       3460006     BI-MGA.1
# 27       3461106     BI-PNO.1
# 28       3461806       BI-PVH
# 29       1760806       VYJEZD
# 30       3471506      BIK-PVH
# 31       3471406      BIK-PVE
# 32       3472406    BIK-ZDM.1
# 33       3466906      BIE-PVE
# 34       3467006      BIE-PVH
# 35       3465706    BIE-LIN.1
# 36       3468106    BIE-VZD.1
# 37       3468006    BIE-VWM.1
# 38       3466406    BIE-PJP.1
# 39       3471706    BIK-SI1.1
# 40       3471106    BIK-PS1.1
# 41       3468306    BIE-ZDM.1
# ...

# %%
predmet_dim['typ_predmetu'].unique()
# Out:
# array(['P', 'V', 'P;', 'PV;', nan, 'N', 'V;', 'PO', 'PO;PZ;', 'O;', 'PO;',
#        'D', 'PO;V;', 'PV;V;', 'PV', 'PZ', 'PZ;V;', 'PV;PZ;', 'PZ;',
#        'PO;PZ;V;', 'P;PO;', 'PO;PV;', 'P;V;', 'PO;V'], dtype=object)

# %%
predmet_dim_bak = predmet_dim[(predmet_dim['typ_predmetu'] != 'V') 
            & (predmet_dim['typ_predmetu'] != 'V;') 
            & (predmet_dim['typ_predmetu'] != 'PV;V') 
            & (predmet_dim['typ_predmetu'] != 'PV;') 
            & (predmet_dim['typ_predmetu'] != 'PV')
            & (predmet_dim['typ_predmetu'].notna())
            & (~predmet_dim['kod_predmetu'].str.contains("21"))
            & (predmet_dim['pocet_kreditu'] != 0.0)
            & (predmet_dim['zpusob_zakonceni'] != "NIC")
            & (~predmet_dim['nazev_predmetu'].str.contains("Fiktivní", case=False))
            & (~predmet_dim['nazev_predmetu'].str.contains("Angličtina", case=False))
            & (~predmet_dim['nazev_predmetu'].str.contains("Španělský", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("bie", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("nie", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("mi", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("ni", case=False))
            & (predmet_dim['forma_studia'].str.contains("p", case=False))
            & (predmet_dim['predmet_id'].isin(courses))]

# %%
#predmet_dim_bak[predmet_dim_bak['predmet_id'] == ]

# %%
rel_courses_bak = predmet_dim_bak['predmet_id'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0c6426bdaa0c> in <module>
# ----> 1 rel_courses_bak = predmet_dim_bak['predmet_id'].unique()
#
# NameError: name 'predmet_dim_bak' is not defined

# %%
rel_courses_bak
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-e1e3c23483c6> in <module>
# ----> 1 rel_courses_bak
#
# NameError: name 'rel_courses_bak' is not defined

# %%
rel_klasifikace_fact_bak = klasifikace_fact[(klasifikace_fact['semestr_id'].isin(sem)) 
                 & (klasifikace_fact['predmet_id'].isin(rel_courses_bak))]

# %%
rel_klasifikace_fact_bak['znamka'].mean()

# %%
rel_klasifikace_fact_bak.groupby(['predmet_id']).mean().sort_values(by=['znamka'], ascending=False)

# %%
predmet_dim_bak[(predmet_dim_bak['predmet_id'] == 1121206) 
               | (predmet_dim_bak['predmet_id'] == 3135306)
               | (predmet_dim_bak['predmet_id'] == 1121906)
               | (predmet_dim_bak['predmet_id'] == 1122106)
               | (predmet_dim_bak['predmet_id'] == 1121506)]

# %%
predmet_dim_mag = predmet_dim[(predmet_dim['typ_predmetu'] != 'V') 
            & (predmet_dim['typ_predmetu'] != 'V;') 
            & (predmet_dim['typ_predmetu'] != 'PV;V') 
            & (predmet_dim['typ_predmetu'] != 'PV;') 
            & (predmet_dim['typ_predmetu'] != 'PV')
            & (predmet_dim['typ_predmetu'].notna())
            & (~predmet_dim['kod_predmetu'].str.contains("21"))
            & (predmet_dim['pocet_kreditu'] != 0.0)
            & (predmet_dim['zpusob_zakonceni'] != "NIC")
            & (~predmet_dim['nazev_predmetu'].str.contains("Fiktivní", case=False))
            & (~predmet_dim['nazev_predmetu'].str.contains("Angličtina", case=False))
            & (~predmet_dim['nazev_predmetu'].str.contains("Španělský", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("bie", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("bi", case=False))
            & (predmet_dim['forma_studia'].str.contains("p", case=False))
            & (~predmet_dim['kod_predmetu'].str.contains("mie", case=False))
            & (predmet_dim['predmet_id'].isin(courses))]

# %%
predmet_dim_mag

# %%
rel_courses_mag = predmet_dim_mag['predmet_id'].unique()

# %%
rel_courses_mag

# %%
rel_klasifikace_fact_mag = klasifikace_fact[(klasifikace_fact['semestr_id'].isin(sem)) 
                 & (klasifikace_fact['predmet_id'].isin(rel_courses_mag))]

# %%
rel_klasifikace_fact_mag['znamka'].mean()

# %%
predmet_dim[predmet_dim['typ_predmetu'].isna()]
# Out:
#       predmet_id kod_predmetu  \
# 13       3468406    BIE-ZMA.1
# 14       3472506    BIK-ZMA.1
# 15       3458806     BI-BIG.1
# 16       3463106       BI-VOL
# 17       3463306     BI-VZD.1
# 18       3462406     BI-SRC.1
# 19       3459706     BI-JPO.1
# 20       3466606    BIE-PS1.1
# 21       3467206    BIE-SI1.1
# 22       3470306    BIK-LIN.1
# 23       3461006     BI-PJP.1
# 24       3461706       BI-PVE
# 25       3461306     BI-PRP.1
# 26       3460006     BI-MGA.1
# 27       3461106     BI-PNO.1
# 28       3461806       BI-PVH
# 30       3471506      BIK-PVH
# 31       3471406      BIK-PVE
# 32       3472406    BIK-ZDM.1
# 33       3466906      BIE-PVE
# 34       3467006      BIE-PVH
# 35       3465706    BIE-LIN.1
# 36       3468106    BIE-VZD.1
# 37       3468006    BIE-VWM.1
# 38       3466406    BIE-PJP.1
# 39       3471706    BIK-SI1.1
# 40       3471106    BIK-PS1.1
# 41       3468306    BIE-ZDM.1
# 42       3461406     BI-PS1.1
# 43       1749106      X000621
# ...

# %% [markdown]
# ### prace_fact

# %%
prace_fact

# %%
prace_fact.info()

# %%
prace_fact_o = prace_fact.copy(deep=True)
prace_fact = prace_fact.drop(columns=['nazev_cs', 'nazev_en'])

# %%
prace_fact

# %% [markdown]
# ### szzk_dim

# %%
szzk_dim

# %%
szzk_dim.info()

# %% [markdown]
# ### student_dim

# %%
student_dim
# Out:
#        studium_id     peridno pohlavi_kod datum_narozeni  \
# 0         1578106     1056306           M     1990-05-18
# 1         3124406     1136106           M     1987-03-10
# 2         1584806     1136106           M     1987-03-10
# 3         6928706     1232506           M     1989-07-06
# 4         8852606     1232506           M     1989-07-06
# ...           ...         ...         ...            ...
# 16426    15167206  8106110089           M     1981-06-11
# 16427     3738406  8108050192           M     1981-08-05
# 16428     8387506  8108050192           M     1981-08-05
# 16429     4750506  8112050419           M     1981-12-05
# 16430     1577906  8202072307           M     1982-02-07
#
#                      misto_narozeni statni_prislusnost_nazev  \
# 0                         Kajrakkum              Tádžikistán
# 1      Štúrovo, Slovenská Republika                Slovensko
# 2      Štúrovo, Slovenská Republika                Slovensko
# ...

# %%
student_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16431 entries, 0 to 16430
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   studium_id                16431 non-null  int64
#  1   peridno                   16431 non-null  int64
#  2   pohlavi_kod               16163 non-null  object
#  3   datum_narozeni            16258 non-null  object
#  4   misto_narozeni            16044 non-null  object
#  5   statni_prislusnost_nazev  16246 non-null  object
#  6   stat_narozeni_nazev       13195 non-null  object
#  7   typ_adresy                16431 non-null  object
#  8   kod_obce                  12242 non-null  float64
#  9   kod_okresu                12506 non-null  float64
#  10  kod_zeme                  16431 non-null  int64
#  11  psc                       12597 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
student_dim_o = student_dim.copy(deep=True)
student_dim = student_dim.drop(columns=['typ_adresy'])

# %%
student_dim

# %% [markdown]
# ### studium_dim

# %%
studium_dim

# %%
studium_dim.info()

# %%
studium_dim.dropna(subset=['zamereni_id'])

# %%
studium_dim['pruchod'].nunique()

# %%
studium_dim_o = studium_dim.copy(deep=True)
studium_dim = studium_dim.drop(columns=['zamereni_id', 'nazev_fakulty', 'fakulta_id', ])

# %%
studium_dim

# %% [markdown]
# ### semestr_dim

# %%
semestr_dim

# %% [markdown]
# ### hodnoceni_dim

# %%
hodnoceni_dim

# %%
hodnoceni_dim['predmet_cislo'].nunique()

# %%
hodnoceni_dim_o = hodnoceni_dim.copy(deep=True)
hodnoceni_dim = hodnoceni_dim.drop(columns=['predmet_cislo'])

# %%
hodnoceni_dim

# %% [markdown]
# # Spojovani datasetu

# %% [markdown]
# ### predmet_klasifikace

# %%
predmet_klasifikace = predmet_dim.merge(klasifikace_fact, how='outer', on='predmet_id')

# %%
predmet_klasifikace

# %% [markdown]
# ### student_prihlaska_studium

# %% [markdown]
# #### student_prihlaska

# %% [markdown]
# oproti zaznamech o studenetu (cca 16.5 tisic) je zaznamu o prihlaskach (cca 3.5 tisic) o hodne mene

# %%
student_prihlaska = student_dim.merge(prihlaska_dim, how='outer', on='studium_id')

# %%
student_prihlaska

# %%
student_prihlaska['studium_id'].nunique()

# %%
student_dim

# %%
student_dim['studium_id'].nunique()

# %%
prihlaska_dim_o

# %%
s = student_prihlaska['studium_id'].value_counts()
student_prihlaska[student_prihlaska.studium_id.isin(s.index[s.gt(1)])]

# %% [markdown]
# ### student_studium

# %%
student_studium = student_dim.merge(studium_dim, how='outer', on='studium_id')

# %%
studium_dim

# %%
student_studium

# %%
student_dim
